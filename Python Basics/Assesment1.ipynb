# %%
abbr = "NLP"
full_text = "Natural Language Processing"
print(f"{abbr} stands for {full_text}")
# Out:
# NLP stands for Natural Language Processing

# %%
# %%writefile contacts.txt
# First_Name, Last_Name, Title, Extension, Email
# Out:
# Writing contacts.txt

# %%
pwd
# Out:
# 'C:\\Users\\Suhas Reddy\\Desktop\\NLP'

# %%
fields = open('contacts.txt','r')

# %%
fields.seek(0)
# Out:
# 0

# %%
fields.read()
# Out:
# 'First_Name, Last_Name, Title, Extension, Email\n'

# %%
fields.close()

# %%
import PyPDF2

# %%
myfile = open("C:\\Users\\Suhas Reddy\\Desktop\\Brundha_J\\Resume\\Brundhaj_final_resume.pdf",'rb')

# %%
pdf_reader = PyPDF2.PdfFileReader(myfile)

# %%
first_page=pdf_reader.getPage(0).extractText()

# %%
print(first_page)
# Out:
#
#
#
# BRUNDHA J
#
#
#
# brundhaj0000@gmail.com
#
#
#
#
#
#
# +91
#
# 9916473211
#
# https://www.linkedin.com/in/brundha
# -
# j
# -
# 5bb6351b4
#
#
#
#
#
# CAREER OBJECTIVE
#
# Personable, organized, and self
# -
# reliant quick responder and innovator that identifies solutions to
# reverse high
# -
# liability projects through to
# timely completion.
#
#
# ACADEMIC
#
# RECORD
#
#
#
# .
#
# Name of
# Program
#
# Board / Institution /
# University
#
# Principal
# Subjects /
# Specialization
#
# % Marks / CGPA
#
# Year of
# Passing
#
# B.
# E
# .
#
# Oxford College of
# Engineering,
# Bangalore
#
# Mechatronics
# Engineering
#
# 1
# st
#
# year
#
# 7.5
# 85
#
# Pursuing
#
# (2021)
#
# 2
# nd
#
# year
#
# 8.27
#
# 3
# rd
#
# year
#
# 8.
# 54
#
# 4
# th
#
# year
#
#
# PUC
#
# Narayana PU College
#
# (state board)
# ,
# Bangalore
#
# Physics,
# Chemistry,
# Mathematics,
# Computer Science
#
#
# 7
# 5
# %
#
# 201
# 7
#
# 10th
#
# The Carmel Convent High
# School (ICSE),
#
# Bangalore
#
# ...

# %%
myfile.close()

# %%
myfile = open('contacts.txt',mode='a+')

# %%
myfile.write(first_page)
myfile.seek(0)
print(myfile.read())
myfile.close()
# Out:
# First_Name, Last_Name, Title, Extension, Email
#
#
#
# BRUNDHA J
#
#
#
# brundhaj0000@gmail.com
#
#
#
#
#
#
# +91
#
# 9916473211
#
# https://www.linkedin.com/in/brundha
# -
# j
# -
# 5bb6351b4
#
#
#
#
#
# CAREER OBJECTIVE
#
# Personable, organized, and self
# -
# reliant quick responder and innovator that identifies solutions to
# reverse high
# -
# liability projects through to
# timely completion.
#
#
# ACADEMIC
#
# RECORD
#
#
#
# .
#
# Name of
# Program
#
# Board / Institution /
# University
#
# Principal
# Subjects /
# Specialization
#
# % Marks / CGPA
#
# Year of
# Passing
#
# B.
# E
# .
#
# Oxford College of
# Engineering,
# Bangalore
#
# Mechatronics
# Engineering
#
# 1
# st
#
# year
#
# 7.5
# 85
#
# Pursuing
#
# (2021)
#
# 2
# nd
#
# year
#
# 8.27
#
# 3
# rd
#
# year
#
# 8.
# 54
#
# 4
# th
#
# year
#
#
# PUC
#
# Narayana PU College
#
# (state board)
# ,
# Bangalore
#
# Physics,
# Chemistry,
# Mathematics,
# Computer Science
#
#
# 7
# 5
# %
#
# 201
# 7
#
# 10th
#
# ...

# %%
import re

# %%
pattern = r"[\w]+@+[\w]+.[\w]{3}"

# %%
print(re.search(pattern,first_page))
# Out:
# <re.Match object; span=(20, 42), match='brundhaj0000@gmail.com'>
